# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
market_data = {
    'Transaction ID': [1, 2, 3, 4, 5, 6, 7, 8],
    'Items': [
        ['T-Shirt', 'Pants', 'Jeans', 'Jersy', 'Socks', 'Basketball', 'Bottle', 'Shorts'],
        ['T-Shirt', 'Jeans'],
        ['Jersy', 'Basketball', 'Socks', 'Bottle'],
        ['Jeans', 'Pants', 'Bottle'],
        ['Shorts', 'Basketball'],
        ['Shorts', 'Jersy'],
        ['T-Shirt'],
        ['Basketball', 'Jersy'],
]}

df = pd.DataFrame(market_data)
df
# Out:
#    Transaction ID                                              Items
# 0               1  [T-Shirt, Pants, Jeans, Jersy, Socks, Basketba...
# 1               2                                   [T-Shirt, Jeans]
# 2               3                 [Jersy, Basketball, Socks, Bottle]
# 3               4                             [Jeans, Pants, Bottle]
# 4               5                               [Shorts, Basketball]
# 5               6                                    [Shorts, Jersy]
# 6               7                                          [T-Shirt]
# 7               8                                [Basketball, Jersy]

# %% [markdown]
# # 使用 TransactionEncoder 將商品轉換為 One-Hot Encoding
#
# - 透過該函數的 `fit` 方法，`TransactionEncoder` 將學習列表（list）或序列（series）中的唯一項目（unique items）。
# - 並透過該 `transform` 方法，將輸入的列表轉換為 NumPy 布林陣列（boolean array）。

# %%
te = TransactionEncoder()
te_ary=te.fit_transform(X=df['Items'])

te_ary
# Out:
# array([[ True,  True,  True,  True,  True,  True,  True,  True],
#        [False, False,  True, False, False, False, False,  True],
#        [ True,  True, False,  True, False, False,  True, False],
#        [False,  True,  True, False,  True, False, False, False],
#        [ True, False, False, False, False,  True, False, False],
#        [False, False, False,  True, False,  True, False, False],
#        [False, False, False, False, False, False, False,  True],
#        [ True, False, False,  True, False, False, False, False]])

# %% [markdown]
# ## 轉換成 Apriori 函數要求資料格式
#
# - **Apriori 函數**要求資料使用 Pandas DataFrame 格式，因此在這裡需要進行轉換：將 array 轉換為 DataFrame。

# %%
data_items_dumm = pd.DataFrame(te_ary, columns=te.columns_)
data_items_dumm
# Out:
#    Basketball  Bottle  Jeans  Jersy  Pants  Shorts  Socks  T-Shirt
# 0        True    True   True   True   True    True   True     True
# 1       False   False   True  False  False   False  False     True
# 2        True    True  False   True  False   False   True    False
# 3       False    True   True  False   True   False  False    False
# 4        True   False  False  False  False    True  False    False
# 5       False   False  False   True  False    True  False    False
# 6       False   False  False  False  False   False  False     True
# 7        True   False  False   True  False   False  False    False

# %% [markdown]
# # 計算支持度達 0.2 的項目集

# %%
frequent_itemsets = apriori(data_items_dumm, use_colnames=True)  # 不訂最低支持度的話，預設為 min_support=0.5
frequent_itemsets
# Out:
#    support      itemsets
# 0      0.5  (Basketball)
# 1      0.5       (Jersy)

# %%
frequent_itemsets = apriori(data_items_dumm, min_support=0.2, use_colnames=True)
frequent_itemsets
# Out:
#     support                            itemsets
# 0     0.500                        (Basketball)
# 1     0.375                            (Bottle)
# 2     0.375                             (Jeans)
# 3     0.500                             (Jersy)
# 4     0.250                             (Pants)
# 5     0.375                            (Shorts)
# 6     0.250                             (Socks)
# 7     0.375                           (T-Shirt)
# 8     0.250                (Basketball, Bottle)
# 9     0.375                 (Jersy, Basketball)
# 10    0.250                (Shorts, Basketball)
# 11    0.250                 (Basketball, Socks)
# 12    0.250                     (Jeans, Bottle)
# 13    0.250                     (Jersy, Bottle)
# 14    0.250                     (Pants, Bottle)
# 15    0.250                     (Socks, Bottle)
# 16    0.250                      (Pants, Jeans)
# 17    0.250                    (Jeans, T-Shirt)
# 18    0.250                     (Jersy, Shorts)
# 19    0.250                      (Jersy, Socks)
# 20    0.250         (Jersy, Basketball, Bottle)
# 21    0.250         (Basketball, Socks, Bottle)
# 22    0.250          (Jersy, Basketball, Socks)
# 23    0.250              (Pants, Jeans, Bottle)
# 24    0.250              (Jersy, Socks, Bottle)
# 25    0.250  (Jersy, Basketball, Socks, Bottle)

# %% [markdown]
# # 計算關聯規則
#
# 沒有指定的門檻值，使用了 `association_rules` 函數來從頻繁項目集（`frequent_itemsets`）中產生關聯規則（association rules）
# 預設情況下，`association_rules` 會只根據 `confidence=0.8` 的條件來生成規則，而 `lift` 並沒有被設定特定的篩選標準。

# %%
association_rules_df = association_rules(frequent_itemsets)
association_rules_df
# Out:
#                     antecedents                  consequents  \
# 0                       (Socks)                 (Basketball)
# 1                       (Pants)                     (Bottle)
# 2                       (Socks)                     (Bottle)
# 3                       (Pants)                      (Jeans)
# 4                       (Socks)                      (Jersy)
# 5               (Jersy, Bottle)                 (Basketball)
# 6          (Basketball, Bottle)                      (Jersy)
# 7           (Basketball, Socks)                     (Bottle)
# 8          (Basketball, Bottle)                      (Socks)
# 9               (Socks, Bottle)                 (Basketball)
# 10                      (Socks)         (Basketball, Bottle)
# 11               (Jersy, Socks)                 (Basketball)
# 12          (Basketball, Socks)                      (Jersy)
# 13                      (Socks)          (Jersy, Basketball)
# 14               (Pants, Jeans)                     (Bottle)
# 15              (Pants, Bottle)                      (Jeans)
# 16              (Jeans, Bottle)                      (Pants)
# 17                      (Pants)              (Jeans, Bottle)
# 18               (Jersy, Socks)                     (Bottle)
# 19              (Jersy, Bottle)                      (Socks)
# 20              (Socks, Bottle)                      (Jersy)
# 21                      (Socks)              (Jersy, Bottle)
# 22   (Jersy, Basketball, Socks)                     (Bottle)
# 23  (Jersy, Basketball, Bottle)                      (Socks)
# 24       (Jersy, Socks, Bottle)                 (Basketball)
# 25  (Basketball, Socks, Bottle)                      (Jersy)
# 26               (Jersy, Socks)         (Basketball, Bottle)
# 27              (Jersy, Bottle)          (Basketball, Socks)
# 28          (Basketball, Socks)              (Jersy, Bottle)
# 29         (Basketball, Bottle)               (Jersy, Socks)
# 30              (Socks, Bottle)          (Jersy, Basketball)
# 31                      (Socks)  (Jersy, Basketball, Bottle)
#
#     antecedent support  consequent support  support  confidence      lift  \
# 0                 0.25               0.500     0.25         1.0  2.000000
# 1                 0.25               0.375     0.25         1.0  2.666667
# 2                 0.25               0.375     0.25         1.0  2.666667
# 3                 0.25               0.375     0.25         1.0  2.666667
# 4                 0.25               0.500     0.25         1.0  2.000000
# 5                 0.25               0.500     0.25         1.0  2.000000
# 6                 0.25               0.500     0.25         1.0  2.000000
# 7                 0.25               0.375     0.25         1.0  2.666667
# 8                 0.25               0.250     0.25         1.0  4.000000
# 9                 0.25               0.500     0.25         1.0  2.000000
# 10                0.25               0.250     0.25         1.0  4.000000
# 11                0.25               0.500     0.25         1.0  2.000000
# 12                0.25               0.500     0.25         1.0  2.000000
# 13                0.25               0.375     0.25         1.0  2.666667
# 14                0.25               0.375     0.25         1.0  2.666667
# 15                0.25               0.375     0.25         1.0  2.666667
# 16                0.25               0.250     0.25         1.0  4.000000
# 17                0.25               0.250     0.25         1.0  4.000000
# 18                0.25               0.375     0.25         1.0  2.666667
# 19                0.25               0.250     0.25         1.0  4.000000
# 20                0.25               0.500     0.25         1.0  2.000000
# 21                0.25               0.250     0.25         1.0  4.000000
# 22                0.25               0.375     0.25         1.0  2.666667
# 23                0.25               0.250     0.25         1.0  4.000000
# 24                0.25               0.500     0.25         1.0  2.000000
# 25                0.25               0.500     0.25         1.0  2.000000
# 26                0.25               0.250     0.25         1.0  4.000000
# 27                0.25               0.250     0.25         1.0  4.000000
# 28                0.25               0.250     0.25         1.0  4.000000
# 29                0.25               0.250     0.25         1.0  4.000000
# 30                0.25               0.375     0.25         1.0  2.666667
# 31                0.25               0.250     0.25         1.0  4.000000
#
#     leverage  conviction  zhangs_metric
# 0    0.12500         inf       0.666667
# 1    0.15625         inf       0.833333
# 2    0.15625         inf       0.833333
# 3    0.15625         inf       0.833333
# 4    0.12500         inf       0.666667
# 5    0.12500         inf       0.666667
# 6    0.12500         inf       0.666667
# 7    0.15625         inf       0.833333
# 8    0.18750         inf       1.000000
# 9    0.12500         inf       0.666667
# 10   0.18750         inf       1.000000
# 11   0.12500         inf       0.666667
# 12   0.12500         inf       0.666667
# 13   0.15625         inf       0.833333
# 14   0.15625         inf       0.833333
# 15   0.15625         inf       0.833333
# 16   0.18750         inf       1.000000
# 17   0.18750         inf       1.000000
# 18   0.15625         inf       0.833333
# 19   0.18750         inf       1.000000
# 20   0.12500         inf       0.666667
# 21   0.18750         inf       1.000000
# 22   0.15625         inf       0.833333
# 23   0.18750         inf       1.000000
# 24   0.12500         inf       0.666667
# 25   0.12500         inf       0.666667
# 26   0.18750         inf       1.000000
# 27   0.18750         inf       1.000000
# 28   0.18750         inf       1.000000
# 29   0.18750         inf       1.000000
# 30   0.15625         inf       0.833333
# 31   0.18750         inf       1.000000

# %% [markdown]
# 指定 `confidence` 最小為 `0.6`

# %%
association_rules_df = association_rules(frequent_itemsets, metric='confidence', min_threshold=0.6)
association_rules_df
# Out:
#                     antecedents                  consequents  \
# 0                      (Bottle)                 (Basketball)
# 1                       (Jersy)                 (Basketball)
# 2                  (Basketball)                      (Jersy)
# 3                      (Shorts)                 (Basketball)
# 4                       (Socks)                 (Basketball)
# 5                       (Jeans)                     (Bottle)
# 6                      (Bottle)                      (Jeans)
# 7                      (Bottle)                      (Jersy)
# 8                       (Pants)                     (Bottle)
# 9                      (Bottle)                      (Pants)
# 10                      (Socks)                     (Bottle)
# 11                     (Bottle)                      (Socks)
# 12                      (Pants)                      (Jeans)
# 13                      (Jeans)                      (Pants)
# 14                      (Jeans)                    (T-Shirt)
# 15                    (T-Shirt)                      (Jeans)
# 16                     (Shorts)                      (Jersy)
# 17                      (Socks)                      (Jersy)
# 18          (Jersy, Basketball)                     (Bottle)
# 19              (Jersy, Bottle)                 (Basketball)
# 20         (Basketball, Bottle)                      (Jersy)
# 21                     (Bottle)          (Jersy, Basketball)
# 22          (Basketball, Socks)                     (Bottle)
# 23         (Basketball, Bottle)                      (Socks)
# 24              (Socks, Bottle)                 (Basketball)
# 25                      (Socks)         (Basketball, Bottle)
# 26                     (Bottle)          (Basketball, Socks)
# 27          (Jersy, Basketball)                      (Socks)
# 28               (Jersy, Socks)                 (Basketball)
# 29          (Basketball, Socks)                      (Jersy)
# 30                      (Socks)          (Jersy, Basketball)
# 31               (Pants, Jeans)                     (Bottle)
# 32              (Pants, Bottle)                      (Jeans)
# 33              (Jeans, Bottle)                      (Pants)
# 34                      (Pants)              (Jeans, Bottle)
# 35                      (Jeans)              (Pants, Bottle)
# 36                     (Bottle)               (Pants, Jeans)
# 37               (Jersy, Socks)                     (Bottle)
# 38              (Jersy, Bottle)                      (Socks)
# 39              (Socks, Bottle)                      (Jersy)
# 40                      (Socks)              (Jersy, Bottle)
# 41                     (Bottle)               (Jersy, Socks)
# 42   (Jersy, Basketball, Socks)                     (Bottle)
# 43  (Jersy, Basketball, Bottle)                      (Socks)
# 44       (Jersy, Socks, Bottle)                 (Basketball)
# 45  (Basketball, Socks, Bottle)                      (Jersy)
# 46          (Jersy, Basketball)              (Socks, Bottle)
# 47               (Jersy, Socks)         (Basketball, Bottle)
# 48              (Jersy, Bottle)          (Basketball, Socks)
# 49          (Basketball, Socks)              (Jersy, Bottle)
# 50         (Basketball, Bottle)               (Jersy, Socks)
# 51              (Socks, Bottle)          (Jersy, Basketball)
# 52                      (Socks)  (Jersy, Basketball, Bottle)
# 53                     (Bottle)   (Jersy, Basketball, Socks)
#
#     antecedent support  consequent support  support  confidence      lift  \
# 0                0.375               0.500    0.250    0.666667  1.333333
# 1                0.500               0.500    0.375    0.750000  1.500000
# 2                0.500               0.500    0.375    0.750000  1.500000
# 3                0.375               0.500    0.250    0.666667  1.333333
# 4                0.250               0.500    0.250    1.000000  2.000000
# 5                0.375               0.375    0.250    0.666667  1.777778
# 6                0.375               0.375    0.250    0.666667  1.777778
# 7                0.375               0.500    0.250    0.666667  1.333333
# 8                0.250               0.375    0.250    1.000000  2.666667
# 9                0.375               0.250    0.250    0.666667  2.666667
# 10               0.250               0.375    0.250    1.000000  2.666667
# 11               0.375               0.250    0.250    0.666667  2.666667
# 12               0.250               0.375    0.250    1.000000  2.666667
# 13               0.375               0.250    0.250    0.666667  2.666667
# 14               0.375               0.375    0.250    0.666667  1.777778
# 15               0.375               0.375    0.250    0.666667  1.777778
# 16               0.375               0.500    0.250    0.666667  1.333333
# 17               0.250               0.500    0.250    1.000000  2.000000
# 18               0.375               0.375    0.250    0.666667  1.777778
# 19               0.250               0.500    0.250    1.000000  2.000000
# 20               0.250               0.500    0.250    1.000000  2.000000
# 21               0.375               0.375    0.250    0.666667  1.777778
# 22               0.250               0.375    0.250    1.000000  2.666667
# 23               0.250               0.250    0.250    1.000000  4.000000
# 24               0.250               0.500    0.250    1.000000  2.000000
# 25               0.250               0.250    0.250    1.000000  4.000000
# 26               0.375               0.250    0.250    0.666667  2.666667
# 27               0.375               0.250    0.250    0.666667  2.666667
# 28               0.250               0.500    0.250    1.000000  2.000000
# 29               0.250               0.500    0.250    1.000000  2.000000
# 30               0.250               0.375    0.250    1.000000  2.666667
# 31               0.250               0.375    0.250    1.000000  2.666667
# 32               0.250               0.375    0.250    1.000000  2.666667
# 33               0.250               0.250    0.250    1.000000  4.000000
# 34               0.250               0.250    0.250    1.000000  4.000000
# 35               0.375               0.250    0.250    0.666667  2.666667
# 36               0.375               0.250    0.250    0.666667  2.666667
# 37               0.250               0.375    0.250    1.000000  2.666667
# 38               0.250               0.250    0.250    1.000000  4.000000
# 39               0.250               0.500    0.250    1.000000  2.000000
# 40               0.250               0.250    0.250    1.000000  4.000000
# 41               0.375               0.250    0.250    0.666667  2.666667
# 42               0.250               0.375    0.250    1.000000  2.666667
# 43               0.250               0.250    0.250    1.000000  4.000000
# 44               0.250               0.500    0.250    1.000000  2.000000
# 45               0.250               0.500    0.250    1.000000  2.000000
# 46               0.375               0.250    0.250    0.666667  2.666667
# 47               0.250               0.250    0.250    1.000000  4.000000
# 48               0.250               0.250    0.250    1.000000  4.000000
# 49               0.250               0.250    0.250    1.000000  4.000000
# 50               0.250               0.250    0.250    1.000000  4.000000
# 51               0.250               0.375    0.250    1.000000  2.666667
# 52               0.250               0.250    0.250    1.000000  4.000000
# 53               0.375               0.250    0.250    0.666667  2.666667
#
#     leverage  conviction  zhangs_metric
# 0   0.062500       1.500       0.400000
# 1   0.125000       2.000       0.666667
# 2   0.125000       2.000       0.666667
# 3   0.062500       1.500       0.400000
# 4   0.125000         inf       0.666667
# 5   0.109375       1.875       0.700000
# 6   0.109375       1.875       0.700000
# 7   0.062500       1.500       0.400000
# 8   0.156250         inf       0.833333
# 9   0.156250       2.250       1.000000
# 10  0.156250         inf       0.833333
# 11  0.156250       2.250       1.000000
# 12  0.156250         inf       0.833333
# 13  0.156250       2.250       1.000000
# 14  0.109375       1.875       0.700000
# 15  0.109375       1.875       0.700000
# 16  0.062500       1.500       0.400000
# 17  0.125000         inf       0.666667
# 18  0.109375       1.875       0.700000
# 19  0.125000         inf       0.666667
# 20  0.125000         inf       0.666667
# 21  0.109375       1.875       0.700000
# 22  0.156250         inf       0.833333
# 23  0.187500         inf       1.000000
# 24  0.125000         inf       0.666667
# 25  0.187500         inf       1.000000
# 26  0.156250       2.250       1.000000
# 27  0.156250       2.250       1.000000
# 28  0.125000         inf       0.666667
# 29  0.125000         inf       0.666667
# 30  0.156250         inf       0.833333
# 31  0.156250         inf       0.833333
# 32  0.156250         inf       0.833333
# 33  0.187500         inf       1.000000
# 34  0.187500         inf       1.000000
# 35  0.156250       2.250       1.000000
# 36  0.156250       2.250       1.000000
# 37  0.156250         inf       0.833333
# 38  0.187500         inf       1.000000
# 39  0.125000         inf       0.666667
# 40  0.187500         inf       1.000000
# 41  0.156250       2.250       1.000000
# 42  0.156250         inf       0.833333
# 43  0.187500         inf       1.000000
# 44  0.125000         inf       0.666667
# 45  0.125000         inf       0.666667
# 46  0.156250       2.250       1.000000
# 47  0.187500         inf       1.000000
# 48  0.187500         inf       1.000000
# 49  0.187500         inf       1.000000
# 50  0.187500         inf       1.000000
# 51  0.156250         inf       0.833333
# 52  0.187500         inf       1.000000
# 53  0.156250       2.250       1.000000

# %% [markdown]
# 指定 `lift` 最小為 `1`

# %%
association_rules_df = association_rules(frequent_itemsets, metric='lift', min_threshold=2)
association_rules_df
# Out:
#                     antecedents                  consequents  \
# 0                  (Basketball)                      (Socks)
# 1                       (Socks)                 (Basketball)
# 2                       (Pants)                     (Bottle)
# 3                      (Bottle)                      (Pants)
# 4                       (Socks)                     (Bottle)
# 5                      (Bottle)                      (Socks)
# 6                       (Pants)                      (Jeans)
# 7                       (Jeans)                      (Pants)
# 8                       (Jersy)                      (Socks)
# 9                       (Socks)                      (Jersy)
# 10              (Jersy, Bottle)                 (Basketball)
# 11         (Basketball, Bottle)                      (Jersy)
# 12                      (Jersy)         (Basketball, Bottle)
# 13                 (Basketball)              (Jersy, Bottle)
# 14          (Basketball, Socks)                     (Bottle)
# 15         (Basketball, Bottle)                      (Socks)
# 16              (Socks, Bottle)                 (Basketball)
# 17                 (Basketball)              (Socks, Bottle)
# 18                      (Socks)         (Basketball, Bottle)
# 19                     (Bottle)          (Basketball, Socks)
# 20          (Jersy, Basketball)                      (Socks)
# 21               (Jersy, Socks)                 (Basketball)
# 22          (Basketball, Socks)                      (Jersy)
# 23                      (Jersy)          (Basketball, Socks)
# 24                 (Basketball)               (Jersy, Socks)
# 25                      (Socks)          (Jersy, Basketball)
# 26               (Pants, Jeans)                     (Bottle)
# 27              (Pants, Bottle)                      (Jeans)
# 28              (Jeans, Bottle)                      (Pants)
# 29                      (Pants)              (Jeans, Bottle)
# 30                      (Jeans)              (Pants, Bottle)
# 31                     (Bottle)               (Pants, Jeans)
# 32               (Jersy, Socks)                     (Bottle)
# 33              (Jersy, Bottle)                      (Socks)
# 34              (Socks, Bottle)                      (Jersy)
# 35                      (Jersy)              (Socks, Bottle)
# 36                      (Socks)              (Jersy, Bottle)
# 37                     (Bottle)               (Jersy, Socks)
# 38   (Jersy, Basketball, Socks)                     (Bottle)
# 39  (Jersy, Basketball, Bottle)                      (Socks)
# 40       (Jersy, Socks, Bottle)                 (Basketball)
# 41  (Basketball, Socks, Bottle)                      (Jersy)
# 42          (Jersy, Basketball)              (Socks, Bottle)
# 43               (Jersy, Socks)         (Basketball, Bottle)
# 44              (Jersy, Bottle)          (Basketball, Socks)
# 45          (Basketball, Socks)              (Jersy, Bottle)
# 46         (Basketball, Bottle)               (Jersy, Socks)
# 47              (Socks, Bottle)          (Jersy, Basketball)
# 48                      (Jersy)  (Basketball, Socks, Bottle)
# 49                 (Basketball)       (Jersy, Socks, Bottle)
# 50                      (Socks)  (Jersy, Basketball, Bottle)
# 51                     (Bottle)   (Jersy, Basketball, Socks)
#
#     antecedent support  consequent support  support  confidence      lift  \
# 0                0.500               0.250     0.25    0.500000  2.000000
# 1                0.250               0.500     0.25    1.000000  2.000000
# 2                0.250               0.375     0.25    1.000000  2.666667
# 3                0.375               0.250     0.25    0.666667  2.666667
# 4                0.250               0.375     0.25    1.000000  2.666667
# 5                0.375               0.250     0.25    0.666667  2.666667
# 6                0.250               0.375     0.25    1.000000  2.666667
# 7                0.375               0.250     0.25    0.666667  2.666667
# 8                0.500               0.250     0.25    0.500000  2.000000
# 9                0.250               0.500     0.25    1.000000  2.000000
# 10               0.250               0.500     0.25    1.000000  2.000000
# 11               0.250               0.500     0.25    1.000000  2.000000
# 12               0.500               0.250     0.25    0.500000  2.000000
# 13               0.500               0.250     0.25    0.500000  2.000000
# 14               0.250               0.375     0.25    1.000000  2.666667
# 15               0.250               0.250     0.25    1.000000  4.000000
# 16               0.250               0.500     0.25    1.000000  2.000000
# 17               0.500               0.250     0.25    0.500000  2.000000
# 18               0.250               0.250     0.25    1.000000  4.000000
# 19               0.375               0.250     0.25    0.666667  2.666667
# 20               0.375               0.250     0.25    0.666667  2.666667
# 21               0.250               0.500     0.25    1.000000  2.000000
# 22               0.250               0.500     0.25    1.000000  2.000000
# 23               0.500               0.250     0.25    0.500000  2.000000
# 24               0.500               0.250     0.25    0.500000  2.000000
# 25               0.250               0.375     0.25    1.000000  2.666667
# 26               0.250               0.375     0.25    1.000000  2.666667
# 27               0.250               0.375     0.25    1.000000  2.666667
# 28               0.250               0.250     0.25    1.000000  4.000000
# 29               0.250               0.250     0.25    1.000000  4.000000
# 30               0.375               0.250     0.25    0.666667  2.666667
# 31               0.375               0.250     0.25    0.666667  2.666667
# 32               0.250               0.375     0.25    1.000000  2.666667
# 33               0.250               0.250     0.25    1.000000  4.000000
# 34               0.250               0.500     0.25    1.000000  2.000000
# 35               0.500               0.250     0.25    0.500000  2.000000
# 36               0.250               0.250     0.25    1.000000  4.000000
# 37               0.375               0.250     0.25    0.666667  2.666667
# 38               0.250               0.375     0.25    1.000000  2.666667
# 39               0.250               0.250     0.25    1.000000  4.000000
# 40               0.250               0.500     0.25    1.000000  2.000000
# 41               0.250               0.500     0.25    1.000000  2.000000
# 42               0.375               0.250     0.25    0.666667  2.666667
# 43               0.250               0.250     0.25    1.000000  4.000000
# 44               0.250               0.250     0.25    1.000000  4.000000
# 45               0.250               0.250     0.25    1.000000  4.000000
# 46               0.250               0.250     0.25    1.000000  4.000000
# 47               0.250               0.375     0.25    1.000000  2.666667
# 48               0.500               0.250     0.25    0.500000  2.000000
# 49               0.500               0.250     0.25    0.500000  2.000000
# 50               0.250               0.250     0.25    1.000000  4.000000
# 51               0.375               0.250     0.25    0.666667  2.666667
#
#     leverage  conviction  zhangs_metric
# 0    0.12500        1.50       1.000000
# 1    0.12500         inf       0.666667
# 2    0.15625         inf       0.833333
# 3    0.15625        2.25       1.000000
# 4    0.15625         inf       0.833333
# 5    0.15625        2.25       1.000000
# 6    0.15625         inf       0.833333
# 7    0.15625        2.25       1.000000
# 8    0.12500        1.50       1.000000
# 9    0.12500         inf       0.666667
# 10   0.12500         inf       0.666667
# 11   0.12500         inf       0.666667
# 12   0.12500        1.50       1.000000
# 13   0.12500        1.50       1.000000
# 14   0.15625         inf       0.833333
# 15   0.18750         inf       1.000000
# 16   0.12500         inf       0.666667
# 17   0.12500        1.50       1.000000
# 18   0.18750         inf       1.000000
# 19   0.15625        2.25       1.000000
# 20   0.15625        2.25       1.000000
# 21   0.12500         inf       0.666667
# 22   0.12500         inf       0.666667
# 23   0.12500        1.50       1.000000
# 24   0.12500        1.50       1.000000
# 25   0.15625         inf       0.833333
# 26   0.15625         inf       0.833333
# 27   0.15625         inf       0.833333
# 28   0.18750         inf       1.000000
# 29   0.18750         inf       1.000000
# 30   0.15625        2.25       1.000000
# 31   0.15625        2.25       1.000000
# 32   0.15625         inf       0.833333
# 33   0.18750         inf       1.000000
# 34   0.12500         inf       0.666667
# 35   0.12500        1.50       1.000000
# 36   0.18750         inf       1.000000
# 37   0.15625        2.25       1.000000
# 38   0.15625         inf       0.833333
# 39   0.18750         inf       1.000000
# 40   0.12500         inf       0.666667
# 41   0.12500         inf       0.666667
# 42   0.15625        2.25       1.000000
# 43   0.18750         inf       1.000000
# 44   0.18750         inf       1.000000
# 45   0.18750         inf       1.000000
# 46   0.18750         inf       1.000000
# 47   0.15625         inf       0.833333
# 48   0.12500        1.50       1.000000
# 49   0.12500        1.50       1.000000
# 50   0.18750         inf       1.000000
# 51   0.15625        2.25       1.000000

# %% [markdown]
# #
